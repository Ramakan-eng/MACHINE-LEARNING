# %%
import pandas as pd
df = pd.DataFrame({'x':[25,26,27,16,14],
                  'y':[1,1,1,0,0]})
df
# Out:
#     x  y
# 0  25  1
# 1  26  1
# 2  27  1
# 3  16  0
# 4  14  0

# %%
X= df[['x']]
Y= df['y']

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X ,Y)
# Out:
# LogisticRegression()

# %%
model.intercept_
# Out:
# array([-13.72764095])

# %%
model.coef_
# Out:
# array([[0.67833386]])

# %%
df
# Out:
#     x  y
# 0  25  1
# 1  26  1
# 2  27  1
# 3  16  0
# 4  14  0

# %%
df['y_lr'] = 0.67833386 * df['x'] - 13.72764095
df
# Out:
#     x  y      y_lr
# 0  25  1  3.230706
# 1  26  1  3.909039
# 2  27  1  4.587373
# 3  16  0 -2.874299
# 4  14  0 -4.230967

# %%
df['p']  = (2.7182 **df['y_lr']) /(2.71 **df['y_lr'] +1)
df
# Out:
#     x  y      y_lr         p
# 0  25  1  3.230706  0.971043
# 1  26  1  3.909039  0.991747
# 2  27  1  4.587373  1.003596
# 3  16  0 -2.874299  0.053418
# 4  14  0 -4.230967  0.014329

# %% [markdown]
# **so where the p_value > 0.5 = 1(replace) or p_value < 0.5 = 0(replace)**

# %%
df['p(1)']  = (2.7182 **df['y_lr']) /(2.71 **df['y_lr'] +1)
df['p(0)'] = 1 - df['p(1)']

df
# Out:
#     x  y      y_lr         p      p(1)      p(0)
# 0  25  1  3.230706  0.971043  0.971043  0.028957
# 1  26  1  3.909039  0.991747  0.991747  0.008253
# 2  27  1  4.587373  1.003596  1.003596 -0.003596
# 3  16  0 -2.874299  0.053418  0.053418  0.946582
# 4  14  0 -4.230967  0.014329  0.014329  0.985671

# %%
df['p(1)']  = (2.7182 **df['y_lr']) /(2.71 **df['y_lr'] +1)
df['p(0)'] = 1 - df['p(1)']

df.iloc[:,[-1,-2]]
# Out:
#        p(0)      p(1)
# 0  0.028957  0.971043
# 1  0.008253  0.991747
# 2 -0.003596  1.003596
# 3  0.946582  0.053418
# 4  0.985671  0.014329

# %%
pd.DataFrame(model.predict_proba(x),columns = ['p0','p1'])  # DataFrame form
# Out:
#          p0        p1
# 0  0.038026  0.961974
# 1  0.019665  0.980335
# 2  0.010077  0.989923
# 3  0.946561  0.053439
# 4  0.985670  0.014330

# %%
model.predict_proba(x)  # array form
# Out:
# array([[0.03802643, 0.96197357],
#        [0.01966528, 0.98033472],
#        [0.01007698, 0.98992302],
#        [0.94656123, 0.05343877],
#        [0.98567001, 0.01432999]])

# %% [markdown]
# **In proba = (p(0),p(1)) which probability is high it will be consider ,if p_value > 0.5 then one(1) and if p_value < 0.5 = 0**
#
# **0.03802643, 0.96197357 so we select 0.96197357 because this value is greater than 0.03802643 and will be 1 because 0.96197357 > 0.5**

# %%
model.predict(x)
# Out:
# array([1, 1, 1, 0, 0], dtype=int64)
