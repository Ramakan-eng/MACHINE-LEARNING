# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\sahur\anaconda3\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\sahur\anaconda3\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\sahur\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\sahur\anaconda3\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\sahur\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\sahur\anaconda3\lib\site-packages (from mlxtend) (3.10.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\sahur\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sahur\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sahur\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sahur\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sahur\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sahur\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\sahur\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sahur\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sahur\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sahur\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sahur\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sahur\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\sahur\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
data = [['milk','bread','rice','book'],
       ['bread','jam','book','pen'],
        ['jam','milk','bread','rice','eggs'],
        ['rice','eggs','pen','book'],
        ['eggs','pen','milk','bread','jam'],
        ['eggs','pen','milk','bread','jam'],
        ['eggs','rice','bread','jam']
       ]

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_array = te.fit_transform(data)
te_array
# Out:
# array([[ True,  True, False, False,  True, False,  True],
#        [ True,  True, False,  True, False,  True, False],
#        [False,  True,  True,  True,  True, False,  True],
#        [ True, False,  True, False, False,  True,  True],
#        [False,  True,  True,  True,  True,  True, False],
#        [False,  True,  True,  True,  True,  True, False],
#        [False,  True,  True,  True, False, False,  True]])

# %% [markdown]
# - This code is used to convert a list of transactions into a format suitable for machine learning models, typically for association rule mining (e.g., Apriori or FP-Growth algorithm).
#
# **🔍 Step-by-Step Breakdown**
# - 1️⃣ Importing TransactionEncoder
#
# ##### from mlxtend.preprocessing import TransactionEncoder
# - TransactionEncoder is a data transformation utility from mlxtend, used for handling transactional datasets (like market basket data).
#
# **2️⃣ Creating an Instance of TransactionEncoder**
#
# ##### te = TransactionEncoder()
# - Initializes an object te to encode transactional data.
#
# **3️⃣ Transforming the Data**
#
# ##### te_array = te.fit_transform(data)
#
# - fit_transform(data) converts the transaction data into a Boolean NumPy array.
#
# - data should be a list of lists, where each inner list is a transaction containing items.
#
# - 🔹 Input (Raw Transaction Data)
#
# | data =                     |
# |----------------------------|
# |[['Milk', 'Bread', 'Butter']|
# |['Bread', 'Butter']|
# |  ['Milk', 'Bread']|
# |  ['Milk', 'Butter']|
#
# **🔹 After Applying TransactionEncoder**
#
# - te_array = te.fit_transform(data)
# - This converts transactions into a Boolean array, where:
#
# - True (1) means the item is present in the transaction.
#
# - False (0) means the item is absent.
#
#   🔹 Output (te_array)
# |Milk|	Bread| |Butter|
# |----|--|-----|--------|
# |1      |1|	    |1|
# |0	    |1|	    |1|
# |1	    |1|	    |0|
# |1	    |0|	    |1|
#
# **📌 Why Use TransactionEncoder?**
#
# - ✅ Converts unordered transactions into a structured numerical format.
# - ✅ Enables easy application of association rule mining algorithms (like Apriori & FP-Growth).
# - ✅ Efficient storage using a sparse Boolean ma

# %%
import pandas as pd
df = pd.DataFrame(te_array,columns = te.columns_)
df
# Out:
#     book  bread   eggs    jam   milk    pen   rice
# 0   True   True  False  False   True  False   True
# 1   True   True  False   True  False   True  False
# 2  False   True   True   True   True  False   True
# 3   True  False   True  False  False   True   True
# 4  False   True   True   True   True   True  False
# 5  False   True   True   True   True   True  False
# 6  False   True   True   True  False  False   True

# %% [markdown]
# **📌  Convert te_array (Encoded Data) into a DataFrame**
#
# ##### df = pd.DataFrame(te_array, columns=te.columns_)
# - te_array → This is the Boolean NumPy array generated by TransactionEncoder.fit_transform(data).
#
# - te.columns_ → This returns the original item names (column names) from the transaction data.
#
# - Creates a DataFrame, where:
#
# - Rows represent transactions.
#
# - Columns represent items (products).
#
# - Values are 1 (True) if the item was in the transaction, 0 (False) if not
#
#  **🛠 Example Execution**
#
# 🔹 Input: Transaction Data
#
# data = [['Milk', 'Bread', 'Butter'],
#         ['Bread', 'Butter'],
#         ['Milk', 'Bread'],
#         ['Milk', 'Butter']]
# - After applying:
#
#
# - from mlxtend.preprocessing import TransactionEncoder
# - te = TransactionEncoder()
# - te_array = te.fit_transform(data)
# - df = pd.DataFrame(te_array, columns=te.columns_)
# - print(df)
#
# **🔹 Output: Encoded DataFrame**
# - Milk	Bread	Butter
# - 1	1	1
# - 0	1	1
# - 1	1	0
# - 1	0	1

# %%
import pandas as pd
df = pd.DataFrame(te_array,columns = te.columns_).astype(int)
df
# Out:
#    book  bread  eggs  jam  milk  pen  rice
# 0     1      1     0    0     1    0     1
# 1     1      1     0    1     0    1     0
# 2     0      1     1    1     1    0     1
# 3     1      0     1    0     0    1     1
# 4     0      1     1    1     1    1     0
# 5     0      1     1    1     1    1     0
# 6     0      1     1    1     0    0     1

# %%
from mlxtend.frequent_patterns import apriori
itemset = apriori(df,min_support = 0.6,use_colnames = True)
itemset
# Out:
# C:\Users\sahur\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support      itemsets
# 0  0.857143       (bread)
# 1  0.714286        (eggs)
# 2  0.714286         (jam)
# 3  0.714286  (bread, jam)

# %% [markdown]
# - This code applies the Apriori algorithm to find frequent itemsets (combinations of items that appear together frequently in transactions).
#
# **🔍 Step-by-Step Breakdown**
# - 1️⃣ Import Apriori Algorithm
#
# - from mlxtend.frequent_patterns import apriori
# - apriori is a function from mlxtend used for frequent itemset mining in association rule learning.
#
# **🛠 Example Output**
# - If the dataset contains:
#
#
# | Milk | Bread | Butter |
# |------|-------|--------|
# |  1   |   1   |   1    |
# |  0   |   1   |   1    |
# |  1   |   1   |   0    |
# |  1   |   0   |   1    |
# - The output itemset might be:
#
#
# | |support|   itemsets|
# |-|------|-----------|
# |0| 0.75 | (Milk)    |
# |1| 0.75 | (Butter)   |
# |2| 0.75 | (Bread)|
# |3| 0.50 | (Milk, Butter)|
# |4| 0.50 | (Bread, Butter)|
# - support → Fraction of transactions containing the itemset.
#
# - itemsets → Frequent item combinations.
#
# **📌 Why Use Apriori?**
# - ✅ Helps find frequent itemsets in market basket analysis.
# - ✅ Used in recommendation systems (e.g., Amazon, grocery stores).
# - ✅ Forms the basis for association rule mining (e.g., Milk → Bread).

# %%
from mlxtend.frequent_patterns import association_rules
res = association_rules(itemset,metric = 'confidence',min_threshold = 0.6)
res
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0     (bread)       (jam)            0.857143            0.714286  0.714286
# 1       (jam)     (bread)            0.714286            0.857143  0.714286
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.833333  1.166667               1.0  0.102041    1.714286
# 1    1.000000  1.166667               1.0  0.102041         inf
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 0            1.0  0.833333   0.416667    0.916667
# 1            0.5  0.833333   1.000000    0.916667

# %% [markdown]
# - This code extracts association rules from the frequent itemsets generated by the Apriori algorithm.
#
# **🔍 Step-by-Step Breakdown**
# - 1️⃣ Import association_rules Function
#
# ##### from mlxtend.frequent_patterns import association_rules
# - This function derives association rules from frequent itemsets.
#
# - Association rules help identify relationships like "If a customer buys Milk, they are likely to buy Bread."
#
# - 2️⃣ Generate Association Rules
#
# ##### res = association_rules(itemset, metric='confidence', min_threshold=0.6)
# - itemset → The frequent itemsets generated using apriori().
#
# - metric='confidence' → The rule evaluation metric (confidence measures how often the rule is correct).
#
# - min_threshold=0.6 → Only rules with a confidence score of at least 60% will be considered.
#
# **🛠 Example Output**
#
# - If itemset contains frequent item combinations, the output res (a DataFrame) might look like this:
#
# |antecedents	|consequents	|support|	confidence|	lift|
# |-----------|----------------|-----------|-------------|----------|
# |(Milk)	|(Bread)|	0.75	|0.80	|1.2|
# |(Butter)|	(Milk)	|0.60	|0.75	|1.5|
#
# - 🔹 What Does This Mean?
# - (Milk) → (Bread)
#
# - Confidence = 0.80 → 80% of the time, when people buy Milk, they also buy Bread.
#
# - Lift = 1.2 → Buying Milk increases the chance of buying Bread by 20% compared to random chance.
#
# - (Butter) → (Milk)
#
# - Confidence = 0.75 → 75% of the time, if a customer buys Butter, they also buy Milk.
#
# - Lift = 1.5 → This association is strong because it increases the chance of buying Milk by 50%.
#
# **📌 Why Use Association Rules?**
#
# - ✅ Helps identify customer buying patterns (useful in market basket analysis).
# - ✅ Used in recommendation systems (e.g., "People who bought this also bought that").
# - ✅ Helps optimize product placement in stor

# %%
result= res[['antecedents','consequents','support','confidence','lift']]
result
# Out:
#   antecedents consequents   support  confidence      lift
# 0     (bread)       (jam)  0.714286    0.833333  1.166667
# 1       (jam)     (bread)  0.714286    1.000000  1.166667

# %% [markdown]
# **🔍 Explanation of the Code:**
#
# ##### result = res[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
#
# -Extracts specific columns from the res DataFrame:
#
# - antecedents → Items on the left-hand side (LHS) of the rule (e.g., "Milk").
#
# - consequents → Items on the right-hand side (RHS) of the rule (e.g., "Bread").
#
# - support → How often the itemset appears in transactions.
#
# - confidence → The probability that if the antecedent is bought, the consequent is also bought.
#
# - lift → How much the antecedent increases the chance of buying the consequent.
#
# **🛠 Example Output**
# |antecedents|	consequents|	support|	confidence|	lift|
# |------|----------|---------|-----------|---|
# |(Milk)|	(Bread)|	0.75|	0.80	|1.2|
# (Butter)|	(Milk)|	0.60|	0.75|	1.5|
